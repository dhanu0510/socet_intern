# %%
import pandas as pd
data = pd.read_excel("IPL.xls")
data.head()
# Out:
#    Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0             1  League Match  Apr 18  2008  Bangalore            Kolkata
# 1             2  League Match  Apr 19  2008     Mohali            Chennai
# 2             3  League Match  Apr 19  2008      Delhi          Rajasthan
# 3             4  League Match  Apr 20  2008    Kolkata          Hyderabad
# 4             5  League Match  Apr 20  2008     Mumbai             Mumbai
#
#   Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0           Bangalore                    222                       3
# 1              Punjab                    240                       5
# 2               Delhi                    129                       8
# 3             Kolkata                    110                      10
# 4           Bangalore                    165                       6
#
#    Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# ...

# %% [markdown]
# ### Task-1

# %%
bat_second_lost = data[data["Team_Batting_Second"] != data["Winner"]]
bat_second_lost
# Out:
#      Match_Number         Match    Date  Year        Venue Team_Batting_First  \
# 0               1  League Match  Apr 18  2008    Bangalore            Kolkata
# 1               2  League Match  Apr 19  2008       Mohali            Chennai
# 7               8  League Match  Apr 23  2008      Chennai            Chennai
# 9              10  League Match  Apr 25  2008       Mohali             Punjab
# 14             15  League Match  Apr 28  2008    Bangalore            Chennai
# ..            ...           ...     ...   ...          ...                ...
# 505           506  League Match  May 14  2015       Mumbai             Mumbai
# 508           509  League Match  May 16  2015  Mumbai (BS)          Rajasthan
# 510           511   Qualifier 1  May 19  2015       Mumbai             Mumbai
# 511           512    Eliminator  May 20  2015         Pune          Bangalore
# 513           514         Final  May 24  2015      Kolkata             Mumbai
#
# ...

# %%
over_15_w = bat_second_lost[bat_second_lost["Bat_Second_15_ov_wkts_lost"] <=4]

# %%
rr = 33/5
over_15_w[over_15_w["Bat_Second_15_ov_Req_RR"]<=rr]
# Out:
#      Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 130           131  League Match  Mar 21  2010    Chennai             Punjab
# 341           342  League Match  Apr 16  2013  Bangalore              Delhi
# 342           343  League Match  Apr 17  2013       Pune          Hyderabad
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 130             Chennai                    136                       8
# 341           Bangalore                    152                       5
# 342                Pune                    119                       8
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# 130                      20.0  ...                    73.0
# 341                      20.0  ...                    84.0
# 342                      20.0  ...                    65.0
#
#      Bat_Second_10_ov_wkts_lost  Bat_Second_10_ov_Req_RR  \
# 130                         1.0                      6.4
# ...

# %% [markdown]
# ### Task2

# %%
over_15_2_w = data[data["Bat_First_15_ov_wkts_lost"] <=2]

# %%
Bat_First_20_ov_score
Bat_First_15_ov_score

# %%
last_5_over = over_15_2_w["Bat_First_20_ov_score"] - over_15_2_w["Bat_First_15_ov_score"]
over_15_2_w["last_5_over"] = last_5_over

task_2 = over_15_2_w[over_15_2_w["last_5_over"]<=25]
# Out:
# <ipython-input-9-3a4eda40066c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over_15_2_w["last_5_over"] = last_5_over

# %%
task_2
# Out:
#      Match_Number         Match    Date  Year   Venue Team_Batting_First  \
# 100           101  League Match  May 14  2009  Durban          Rajasthan
#
#     Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 100              Mumbai                    145                       7
#
#      Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_wkts_lost  \
# 100                      20.0  ...                         3.0
#
#      Bat_Second_10_ov_Req_RR  Bat_Second_15_ov_score  \
# 100                      9.2                    98.0
#
#      Bat_Second_15_ov_wkts_lost  Bat_Second_15_ov_Req_RR  \
# 100                         5.0                      9.6
#
#     Bat_Second_20_ov_score Bat_Second_20_ov_wkts_lost  Match_Time  \
# 100                  143.0                       10.0     Evening
#
#     Duckworth Lewis Used  last_5_over
# 100                  NaN         22.0
#
# [1 rows x 44 columns]
